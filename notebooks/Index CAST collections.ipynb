# %%
from pathlib import Path
# Paths relative to this notebook's location (notebooks/ dir)
PROJECT_ROOT = Path().resolve().parent
DRHARD_ROOT = PROJECT_ROOT.parent / "DRhard"

# %%
# %load_ext autoreload
# %autoreload 2

from time import time
import pandas as pd
import numpy as np
import os

# %%
import pyterrier as pt
pt.init()
# Out:
# PyTerrier 0.7.1 has loaded Terrier 5.6 (built by craigmacdonald on 2021-09-17 13:27)
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.

# %%
CAST2020 = "/data3/crisIda_Shared/conversational-cache/collections/CAST_2020/"

# %%
files = [CAST2020 + "CAST-2020.trec"]

# build the index
# the default Terrier indexing configuration is to use a term pipeline of Stopwords,PorterStemmer
indexer = pt.TRECCollectionIndexer(str(PROJECT_ROOT / "indexes/CAST2020-stemmed"),
                                   verbose=True,
                                   blocks=False,
                                   meta={'docno' : 47})

# indexer.setProperty("termpipelines", "")
indexref = indexer.index(files)

# load the index, print the statistics
index = pt.IndexFactory.of(indexref)
print(index.getCollectionStatistics().toString())
# Out:
# 2files [00:00,  6.56files/s]
# 13:07:57.111 [main] WARN org.terrier.structures.indexing.Indexer - Adding an empty document to the index (MARCO_55893) - further warnings are suppressed

# %%
CAST2021 = "/data3/crisIda_Shared/conversational-cache/collections/CAST_2021/"

# %%
# TODO: replace with the actual CAST2021 collection filename
# files = [CAST2021 + "<collection-filename>.trec"]

# build the index
# indexer = pt.TRECCollectionIndexer("/path/to/indexes/CAST2021-stemmed",
#                                    verbose=True, blocks=False, meta={'docno': 47})
# indexref = indexer.index(files)
# index = pt.IndexFactory.of(indexref)
# print(index.getCollectionStatistics().toString())
